# %%
import sys
sys.path.append('..')
from src.bq_client import run_query
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# - Testing the experiment group query

# %%
# Read the experiment groups file
with open('../src/queries/experiment_groups.sql', 'r') as f:
    experiment_groups_sql = f.read()

# Execute to fetch your core mathematical numbers
df_groups = run_query(experiment_groups_sql)

# Display the final data frame
df_groups
